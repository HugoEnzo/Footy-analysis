# %%
import pandas as pd 
from statsbombpy import sb
import numpy as np

# %%
competitions = sb.competitions()
competitions
# Out:
# C:\Users\sivas\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsbombpy\api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
#     competition_id  season_id   country_name        competition_name  \
# 0                9        281        Germany           1. Bundesliga
# 1                9         27        Germany           1. Bundesliga
# 2             1267        107         Africa  African Cup of Nations
# 3               16          4         Europe        Champions League
# 4               16          1         Europe        Champions League
# ..             ...        ...            ...                     ...
# 69              55         43         Europe               UEFA Euro
# 70              35         75         Europe      UEFA Europa League
# 71              53        106         Europe       UEFA Women's Euro
# 72              72        107  International       Women's World Cup
# ...

# %%
competitions[competitions["competition_name"]=='1. Bundesliga']
# Out:
#    competition_id  season_id country_name competition_name competition_gender  \
# 0               9        281      Germany    1. Bundesliga               male
# 1               9         27      Germany    1. Bundesliga               male
#
#    competition_youth  competition_international season_name  \
# 0              False                      False   2023/2024
# 1              False                      False   2015/2016
#
#                 match_updated           match_updated_360  \
# 0  2024-07-15T14:15:54.671676  2024-07-15T14:17:00.877356
# 1  2024-05-19T11:11:14.192381                        None
#
#           match_available_360             match_available
# 0  2024-07-15T14:17:00.877356  2024-07-15T14:15:54.671676
# 1                        None  2024-05-19T11:11:14.192381

# %%
matches = sb.matches(competition_id=9, season_id=281)
matches[matches['home_team']=='Bayer Leverkusen']
# Out:
# C:\Users\sivas\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsbombpy\api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
#     match_id  match_date      kick_off              competition     season  \
# 0    3895302  2024-04-14  17:30:00.000  Germany - 1. Bundesliga  2023/2024
# 4    3895348  2024-05-18  16:30:00.000  Germany - 1. Bundesliga  2023/2024
# 5    3895286  2024-03-30  16:30:00.000  Germany - 1. Bundesliga  2023/2024
# 7    3895250  2024-02-23  21:30:00.000  Germany - 1. Bundesliga  2023/2024
# 8    3895266  2024-03-10  20:30:00.000  Germany - 1. Bundesliga  2023/2024
# 10   3895180  2023-12-17  18:30:00.000  Germany - 1. Bundesliga  2023/2024
# 12   3895121  2023-10-29  18:30:00.000  Germany - 1. Bundesliga  2023/2024
# 13   3895107  2023-10-08  16:30:00.000  Germany - 1. Bundesliga  2023/2024
# 15   3895139  2023-11-12  16:30:00.000  Germany - 1. Bundesliga  2023/2024
# ...

# %%
BayerWerder = sb.
BayerWerder
# Out:
#   Cell In[49], line 1
#     BayerWerder = sb.
#                      ^
# SyntaxError: invalid syntax

# %%
df=pd.read_csv("europaFinal.csv")

# %%
df.head()
# Out:
#      minute  second             teamId     x     y     period  type  \
# 2         0     0.0  Manchester United  49.9  50.0  FirstHalf  Pass
# 119       6    11.0  Manchester United  65.4  96.8  FirstHalf  Pass
# 130       6    55.0  Manchester United  69.8  30.3  FirstHalf  Pass
# 133       7     1.0  Manchester United  84.3  23.3  FirstHalf  Pass
# 185      12    20.0  Manchester United  39.0  64.8  FirstHalf  Pass
#
#         outcome  playerId  endX  endY  x1_bin
# 2    Successful      18.0  31.5  59.6       5
# 119  Successful      18.0  63.3  87.8       7
# 130  Successful      18.0  74.4  18.8       8
# 133  Successful      18.0  86.0  20.0      10
# 185  Successful      18.0  32.8  72.9       3

# %%
df= df.loc[(df['playerId']==18.0) & (df["teamId"]=='Manchester United')& (df["type"]=="Pass")&(df["outcome"]=="Successful")]
df

# %%
xt_grid = pd.read_csv("xT_Grid.csv", header = None)

# %%
xt_grid
# Out:
#          0         1         2         3         4         5         6   \
# 0  0.006383  0.007796  0.008449  0.009777  0.011263  0.012483  0.014736
# 1  0.007501  0.008786  0.009424  0.010595  0.012147  0.013845  0.016118
# 2  0.008880  0.009777  0.010013  0.011105  0.012692  0.014291  0.016856
# 3  0.009411  0.010827  0.010165  0.011324  0.012626  0.014846  0.016895
# 4  0.009411  0.010827  0.010165  0.011324  0.012626  0.014846  0.016895
# 5  0.008880  0.009777  0.010013  0.011105  0.012692  0.014291  0.016856
# 6  0.007501  0.008786  0.009424  0.010595  0.012147  0.013845  0.016118
# 7  0.006383  0.007796  0.008449  0.009777  0.011263  0.012483  0.014736
#
#          7         8         9         10        11
# 0  0.017451  0.021221  0.027563  0.034851  0.037926
# 1  0.018703  0.024015  0.029533  0.040670  0.046477
# 2  0.019351  0.024122  0.028552  0.054911  0.064426
# 3  0.019971  0.023851  0.035113  0.108051  0.257454
# 4  0.019971  0.023851  0.035113  0.108051  0.257454
# ...

# %%
xt = np.array(xt_grid)

# %%
xt
# Out:
# array([[0.00638303, 0.00779616, 0.00844854, 0.00977659, 0.01126267,
#         0.01248344, 0.01473596, 0.0174506 , 0.02122129, 0.02756312,
#         0.03485072, 0.0379259 ],
#        [0.00750072, 0.00878589, 0.00942382, 0.0105949 , 0.01214719,
#         0.0138454 , 0.01611813, 0.01870347, 0.02401521, 0.02953272,
#         0.04066992, 0.04647721],
#        [0.0088799 , 0.00977745, 0.01001304, 0.01110462, 0.01269174,
#         0.01429128, 0.01685596, 0.01935132, 0.0241224 , 0.02855202,
#         0.05491138, 0.06442595],
#        [0.00941056, 0.01082722, 0.01016549, 0.01132376, 0.01262646,
#         0.01484598, 0.01689528, 0.0199707 , 0.02385149, 0.03511326,
#         0.10805102, 0.25745362],
#        [0.00941056, 0.01082722, 0.01016549, 0.01132376, 0.01262646,
#         0.01484598, 0.01689528, 0.0199707 , 0.02385149, 0.03511326,
#         0.10805102, 0.25745362],
#        [0.0088799 , 0.00977745, 0.01001304, 0.01110462, 0.01269174,
# ...

# %%
xt_rows, xt_cols = xt.shape

# %%
df['x1_bin'] = pd.cut(df['x'],bins = xt_cols, labels = False)
df['x2_bin'] = pd.cut(df['endX'],bins = xt_cols, labels = False)
df['y1_bin'] = pd.cut(df['y'],bins = xt_rows, labels = False)
df['y2_bin'] = pd.cut(df['endY'],bins = xt_rows, labels = False)
# Out:
# C:\Users\sivas\AppData\Local\Temp\ipykernel_1052\4042125900.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['x1_bin'] = pd.cut(df['x'],bins = xt_cols, labels = False)
# C:\Users\sivas\AppData\Local\Temp\ipykernel_1052\4042125900.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['x2_bin'] = pd.cut(df['endX'],bins = xt_cols, labels = False)
# C:\Users\sivas\AppData\Local\Temp\ipykernel_1052\4042125900.py:3: SettingWithCopyWarning:
# ...

# %%
df.head()
# Out:
#      minute  second             teamId     x     y     period  type  \
# 2         0     0.0  Manchester United  49.9  50.0  FirstHalf  Pass
# 119       6    11.0  Manchester United  65.4  96.8  FirstHalf  Pass
# 130       6    55.0  Manchester United  69.8  30.3  FirstHalf  Pass
# 133       7     1.0  Manchester United  84.3  23.3  FirstHalf  Pass
# 185      12    20.0  Manchester United  39.0  64.8  FirstHalf  Pass
#
#         outcome  playerId  endX  endY  x1_bin  x2_bin  y1_bin  y2_bin
# 2    Successful      18.0  31.5  59.6       5       3       4       4
# 119  Successful      18.0  63.3  87.8       7       7       7       7
# 130  Successful      18.0  74.4  18.8       8       9       2       1
# 133  Successful      18.0  86.0  20.0      10      10       1       1
# 185  Successful      18.0  32.8  72.9       3       3       5       5

# %%
df["start_zone_value"] = df[['x1_bin','y1_bin']],apply(lambda x: xt[x[1]][x[0]], axis = 1)
